# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f 50 = [0.46120213251203296, 0.47171045890492214, 0.480009557175635, 0.49240400897642816, 0.49576770628070654, 0.5171643422787707, 0.5495724271683585, 0.646096913475345, 0.6588561688164143, 0.659088721668241, 0.6629335074056546]
len(f50)
# Out:
# 11

# %%
f30 = [0.3908574429963948, 0.40145462522096254, 0.5101388365379711, 0.5275138442009039, 0.5385717850420191, 0.5474133619739777, 0.5625357727336325, 0.5793043863779395, 0.5810980280448899, 0.6134732848657745, 0.6300349325824303]
len(f30)
# Out:
# 11

# %%
f80 = [0.2560457337303482, 0.345702034323507, 0.4374402047118794, 0.4496445789478811, 0.4744578806485343, 0.47660138285993286, 0.5058757521890941, 0.5059114629065451, 0.5204185141747281, 0.5686753861965035, 0.6300349325824303]
len(f80)
# Out:
# 11

# %% [markdown]
# # Fitness Graph with different Swarm population
# ## 1. Normal Nodes with single Sink

# %%
# 50 swarms
x = [(i + 1)*4 for i in range(11)]

plt.plot(x, f50, label = "IP = 50")
plt.plot(x, f30, label = "IP = 30")
plt.plot(x, f80, label = "IP = 80")
#plt.title("The behavior of FJAPSO on IP, fitness value and iterations")
plt.xlabel("Iterations")
plt.ylabel("Fitness");
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Normal nodes with multiple Sinks

# %%
f50 = [0.8035952406009085, 0.9310328845457674, 0.9773696923425688, 1.0471998838751702, 1.0959733263505649, 1.154716140853222, 1.1796951924348078, 1.1965058756063607, 1.2020729351807824, 1.217363982315796, 1.2302568169152537]#, 1.2543376889927156, 1.2576762290520973]#, 1.2890043966381899, 1.3252796968704716, 1.3671174896087623, 1.3943055768379429, 1.3958128762862156, 1.4070200265120218, 1.4228837993392907, 1.426183426675961, 1.4329914980231968, 1.4380849303210275, 1.4401973327195672, 1.4447874730738182, 1.46036204406752, 1.4672626626175138, 1.4995558381565468, 1.5229168076427853
len(f50)
# Out:
# 11

# %%
f30 = [0.8270818585003757, 0.8502897348372846, 0.8697974545450974, 0.8948630379036129, 0.9112626976770459, 0.9166348095675857, 0.9412347409982036, 1.013979588130774, 1.022527311913549, 1.0425885696089174, 1.0660861491982851]#, 1.086614766321047, 1.1053116321973813, 1.1060555539192722, 1.1182005628298008, 1.1859013362465498, 1.1917493737049678, 1.2488242737063007, 1.2833304686868514, 1.3196202097463383, 1.3407030973793577, 1.347026623469339, 1.3769581277829555, 1.3818600094461062, 1.39228414365985, 1.4374517648849072, 1.5022849990251934, 1.5190577143921813, 1.5201142543801232, 1.5237763350420541]
len(f30)
# Out:
# 11

# %%
f80 = [0.7571215488698848, 0.795828442562092, 0.9536128250052699, 0.9636055127192507, 1.0099813777226199, 1.0232311243163659, 1.052795024661518, 1.061768293407157, 1.0745980164756663, 1.0809879492131529, 1.100839038134434]#, 1.1759462726517735, 1.1886481063206742, 1.2741584045335304, 1.2856316767955116, 1.308328509021351, 1.3102523950410423, 1.3182985805666507, 1.3487664884163273, 1.3702399746013039, 1.3737361510154258, 1.3804980587309903, 1.389229727220059, 1.411521564999599, 1.4309486246879055, 1.4412734220280579, 1.4671743279321348, 1.4695602202302762, 1.4874669887222414, 1.5104784540626475, 1.5111534766973798, 1.5142440845889924, 1.5148665988286032, 1.5185226016852518, 1.536317229888276]
len(f80)
# Out:
# 11

# %%
# 50 swarms
x = [(i + 1)*4 for i in range(11)]

plt.plot(x, f50, label = "IP = 50")
plt.plot(x, f30, label = "IP = 30")
plt.plot(x, f80, label = "IP = 80")
#plt.title("The behavior of FJAPSO on IP, fitness value and iterations")
plt.xlabel("Iterations")
plt.ylabel("Fitness");
plt.legend()
plt.show()

# %% [markdown]
# ## 3. heterogenous Node with single sink

# %%
f50 = [0.5803819876489813, 0.7128056950001397, 0.7394193280337534, 0.7518654949896175, 0.7715924409951398, 0.8147354905008874, 0.817884562556398, 0.8497020514468372, 0.8713023185587977, 0.8806685425576114, 0.9162127364665383]
len(f50)
# Out:
# 11

# %%
f30=[0.5949600415233057, 0.6450828192359387, 0.6882967357377753, 0.7021504202909851, 0.7176494055977591,0.7206173799404314,0.7461787698717567, 0.790968365408506, 0.8021429999599528, 0.8234478917663252,0.8413657105865958]
len(f30)
# Out:
# 11

# %%
f80=[0.52112898069904, 0.5359236972443157, 0.591894275817946, 0.6312149161641822, 0.6568938902275759, 0.6995904000801918, 0.7982681607638441, 0.8459193747336291, 0.8630250046582509, 0.9020688116785925, 0.9246528055483716]
len(f80)
# Out:
# 11

# %%
# 50 swarms
x = [(i + 1)*4 for i in range(11)]

plt.plot(x, f50, label = "IP = 50")
plt.plot(x, f30, label = "IP = 30")
plt.plot(x, f80, label = "IP = 80")
#plt.title("The behavior of FJAPSO on IP, fitness value and iterations")
plt.xlabel("Iterations")
plt.ylabel("Fitness");
plt.legend()
plt.show()

# %% [markdown]
# ## 4.heterogenous Nodes with multiple sinks

# %%
f50 = [0.891983333713555, 1.0720086176830588, 1.2039462208224854, 1.2416955897176942, 1.2680480781911831, 1.2855718239602876, 1.3493573756428425, 1.4287977246092949, 1.475293567675501, 1.5085453347723463, 1.6029797930925593]#, 1.6260021615702185, 1.6653367455097885, 1.67195156095389, 1.7235326593762685, 1.727862056106293, 1.7393783645075254, 1.742957983707072]
len(f50)
# Out:
# 11

# %%
f30=[0.9480742906506255, 1.090060216215006, 1.1461882965652828, 1.1866158969795395, 1.187196597744291, 1.276693306001896, 1.3026574100353576, 1.318520779553887, 1.351418982527507, 1.3733411239219138, 1.390921404939967]
len(f30)
# Out:
# 11

# %%
f80=[0.989643787926549, 1.2254253181805983, 1.2677202476543534, 1.3419374164935893, 1.3806845808047026, 1.398698991559846, 1.4354927747113004, 1.45821177383205, 1.5384404899935058,1.5659607377551779, 1.5796585300427421]
len(f80)
# Out:
# 11

# %%
# 50 swarms
x = [(i + 1)*4 for i in range(11)]

plt.plot(x, f50, label = "IP = 50")
plt.plot(x, f30, label = "IP = 30")
plt.plot(x, f80, label = "IP = 80")
#plt.title("The behavior of FJAPSO on IP, fitness value and iterations")
plt.xlabel("Iterations")
plt.ylabel("Fitness");
plt.legend()
plt.show()
